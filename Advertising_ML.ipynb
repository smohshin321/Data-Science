# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:\\Users\\smohs_\\Machine_Learning\\PrepZee\\Advertising\\Advertising01.csv")

# %%
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
# data.drop(columns=['Age1','Age2'])

# %%
#checking the null value
data.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
data.rename(columns={'Unnamed: 0': "SL"})
# Out:
#       SL     TV  Radio  Newspaper  Sales
# 0      1  230.1   37.8       69.2   22.1
# 1      2   44.5   39.3       45.1   10.4
# 2      3   17.2   45.9       69.3    9.3
# 3      4  151.5   41.3       58.5   18.5
# 4      5  180.8   10.8       58.4   12.9
# ..   ...    ...    ...        ...    ...
# 195  196   38.2    3.7       13.8    7.6
# 196  197   94.2    4.9        8.1    9.7
# 197  198  177.0    9.3        6.4   12.8
# 198  199  283.6   42.0       66.2   25.5
# 199  200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
data_new = data.drop('Unnamed: 0', axis=1)

# %%
data_new.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
# pandas_profiling.ProfileReport(advt) # complete HTML overall Summarised report 

# new name is ydata-profiling 
# !pip install ydata-profiling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: visions 0.8.1 does not provide the extra 'type_image_path'

# %%
def var_summary(x):
    return pd.Series([x.count(), 
        x.isnull().sum(),
        x.sum(),
        x.mean(),
        x.median(),
        x.std(),
        x.var(),
        x.min(),
        x.quantile(0.01),
        x.quantile(0.05),
        x.quantile(0.10),
        x.quantile(0.25),
        x.quantile(0.50),
        x.quantile(0.75),
        x.quantile(0.90),
        x.quantile(0.95),
        x.quantile(0.99),
        x.max()],
        index=['N',
               'NMISS',
               'SUM',
               'MEAN', 
               'MEDIAN', 
               'STD',
               'VAR', 
               'MIN', 
               'P1',
               'P5',
               'P10',
               'P25/Q1',
               'P50/Q2',
               'P75/Q3',
               'P90',
               'P95', 
               'P99',
               'MAX'])

# %%
var_summary(data_new)
# Out:
# N         TV           200
# Radio        200
# Newspaper   ...
# NMISS     TV           0
# Radio        0
# Newspaper    0
# S...
# SUM       TV           29408.5
# Radio         4652.8
# News...
# MEAN      TV           147.0425
# Radio         23.2640
# Ne...
# MEDIAN    TV           149.75
# Radio         22.90
# Newspa...
# STD       TV           85.854236
# Radio        14.846809
# ...
# VAR       TV           7370.949893
# Radio         220.427...
# MIN       TV           0.7
# Radio        0.0
# Newspaper   ...
# P1        TV           5.387
# Radio        0.399
# Newspape...
# P5        TV           13.195
# Radio         1.995
# Newspa...
# P10       TV           24.88
# Radio         3.40
# Newspape...
# P25/Q1    TV           74.375
# Radio         9.975
# Newspa...
# P50/Q2    TV           149.75
# Radio         22.90
# Newspa...
# P75/Q3    TV           218.825
# Radio         36.525
# News...
# P90       TV           261.44
# Radio         43.52
# Newspa...
# ...

# %%
from ydata_profiling import ProfileReport
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
profile = ProfileReport(data_new)
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.16.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-11-04 02:43:06.716254&quot;&gt;&lt;title&gt;YData Profiling Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
var_summary(data_new).T
# Out:
# N         TV           200
# Radio        200
# Newspaper   ...
# NMISS     TV           0
# Radio        0
# Newspaper    0
# S...
# SUM       TV           29408.5
# Radio         4652.8
# News...
# MEAN      TV           147.0425
# Radio         23.2640
# Ne...
# MEDIAN    TV           149.75
# Radio         22.90
# Newspa...
# STD       TV           85.854236
# Radio        14.846809
# ...
# VAR       TV           7370.949893
# Radio         220.427...
# MIN       TV           0.7
# Radio        0.0
# Newspaper   ...
# P1        TV           5.387
# Radio        0.399
# Newspape...
# P5        TV           13.195
# Radio         1.995
# Newspa...
# P10       TV           24.88
# Radio         3.40
# Newspape...
# P25/Q1    TV           74.375
# Radio         9.975
# Newspa...
# P50/Q2    TV           149.75
# Radio         22.90
# Newspa...
# P75/Q3    TV           218.825
# Radio         36.525
# News...
# P90       TV           261.44
# Radio         43.52
# Newspa...
# ...

# %%
data_new.describe().T

# %%
data_new.apply(lambda x:var_summary(x)).T
# Out:
#                N  NMISS      SUM      MEAN  MEDIAN        STD          VAR  \
# TV         200.0    0.0  29408.5  147.0425  149.75  85.854236  7370.949893
# Radio      200.0    0.0   4652.8   23.2640   22.90  14.846809   220.427743
# Newspaper  200.0    0.0   6110.8   30.5540   25.75  21.778621   474.308326
# Sales      200.0    0.0   2804.5   14.0225   12.90   5.217457    27.221853
#
#            MIN     P1      P5    P10  P25/Q1  P50/Q2   P75/Q3     P90  \
# TV         0.7  5.387  13.195  24.88  74.375  149.75  218.825  261.44
# Radio      0.0  0.399   1.995   3.40   9.975   22.90   36.525   43.52
# Newspaper  0.3  0.999   3.600   5.99  12.750   25.75   45.100   59.07
# Sales      1.6  4.784   6.600   7.96  10.375   12.90   17.400   21.71
#
#                P95      P99    MAX
# TV         280.735  292.907  296.4
# Radio       46.810   49.400   49.6
# Newspaper   71.825   89.515  114.0
# Sales       23.800   25.507   27.0

# %%
data_new.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
# Assumption No. 3  - Is there a relationship between sales[Y] and spend[X] various advertising channels?
# Sales Vs. Newspaper advertisement spends

# to show the plot un Jupyter GUI
# %matplotlib inline 

sns.jointplot(x =data_new['Newspaper'], y =data_new['Sales'], data = data_new ) # Both Bi-variate(Scatter) + Univariate(Histogram)
#to show the plot
plt.show()

# %%
# You can compute the correlation coefficient (r-value) like this:If you get a value near 0, it means there’s no significant correlation.

# %%
# Visualizing pairwise correleation
sns.pairplot( data_new )
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# correlation coefficient (r-value) like this:

data_new[['Newspaper','Sales']].corr()

# If you get a value near 0, it means there’s no significant correlation.
# Out:
#            Newspaper     Sales
# Newspaper   1.000000  0.228299
# Sales       0.228299  1.000000

# %%
# Interpretation:

# Correlation coefficient (r) = 0.2283

# The value ranges between -1 and +1:

# +1 → Perfect positive relationship

# 0 → No relationship

# -1 → Perfect negative relationship

# 0.2283 = weak positive correlation
# This means:
# As Newspaper advertising spending increases, Sales tend to increase slightly — but the relationship is very weak and likely not statistically significant.

# %%
data_new.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
data_new[['TV','Radio','Newspaper','Sales']].corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.782224
# Radio      0.054809  1.000000   0.354104  0.576223
# Newspaper  0.056648  0.354104   1.000000  0.228299
# Sales      0.782224  0.576223   0.228299  1.000000

# %%
# Let’s create side-by-side scatterplots with regression lines:

fig, axes = plt.subplots(1,3, figsize=(15,5))

sns.regplot(x = "TV",y = "Sales",data = data_new, ax = axes[0],color = 'b')
axes[0].set_title ("Tv vs Sales")

sns.regplot(x = "Radio",y = "Sales",data = data_new, ax = axes[1],color = 'g')
axes[0].set_title ("Radio vs Sales")


sns.regplot(x = "Newspaper",y = "Sales",data = data_new, ax = axes[2],color = 'r')
axes[0].set_title ("Newspaper vs Sales")

plt.tight_layout()

plt.show()

# %%
# let’s statistically confirm which advertising channels (TV, Radio, Newspaper) 
# ...significantly affect Sales using simple linear regression and then multiple regression.

import statsmodels.api as sm


# Simple Linear Regressions (one predictor at a time)

# Let’s check the impact of each channel individually on Sales:

#TV vs Sales

X = data_new['TV']
y = data_new['Sales']

X = sm.add_constant (X) # add intercept
model_tv = sm.OLS(y,X).fit()

print (model_tv.summary())


#Radio vs Sales

X = data_new['Radio']
y = data_new['Sales']

X = sm.add_constant (X) # add intercept
model_radio = sm.OLS(y,X).fit()

print (model_radio.summary())



#Newspaper vs Sales

X = data_new['Newspaper']
y = data_new['Sales']

X = sm.add_constant (X) # add intercept
model_newspaper = sm.OLS(y,X).fit()

print (model_newspaper.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     312.1
# Date:                Mon, 03 Nov 2025   Prob (F-statistic):           1.47e-42
# Time:                        22:30:40   Log-Likelihood:                -519.05
# No. Observations:                 200   AIC:                             1042.
# Df Residuals:                     198   BIC:                             1049.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.0326      0.458     15.360      0.000       6.130       7.935
# ...

# %%
# Now run the multiple regression (all three predictors together):

X = data_new[['TV', 'Radio', 'Newspaper']]
y = data_new['Sales']
X = sm.add_constant(X)
model_multi = sm.OLS(y, X).fit()
print(model_multi.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Mon, 03 Nov 2025   Prob (F-statistic):           1.58e-96
# Time:                        22:33:51   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.9389      0.312      9.422      0.000       2.324       3.554
# ...

# %%
# Key Insights

# The model fits the data extremely well (R² = 0.897).

# TV and Radio together explain nearly all of the variation in Sales.

# Newspaper spending can be safely reduced or reallocated — it doesn’t improve Sales significantly once other media are accounted for.

# The negative sign on Newspaper (-0.001) likely results from multicollinearity (spending overlap) or noise — not a real negative effect.

# Final Regression Equation
# Sales = 2.939 + 0.0458(TV)+0.1885(Radio)−0.0010 (Newspaper )
# Sales=2.939+0.0458(TV)+0.1885(Radio)−0.0010(Newspaper)
