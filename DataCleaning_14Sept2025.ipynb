# %%
import pandas as pd

# %%
df= pd.read_csv("C:\\Users\\smohs_\\Machine_Learning\\PrepZee\\Titanic\\0.01 - Titanic Data.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
ORD=pd.read_excel("C:\\Users\\smohs_\\Machine_Learning\\PrepZee\\Data_Superstore\\Sample - Superstore.xls",sheet_name="Orders")
RTN=pd.read_excel("C:\\Users\\smohs_\\Machine_Learning\\PrepZee\\Data_Superstore\\Sample - Superstore.xls",sheet_name="Returns")
PPL=pd.read_excel("C:\\Users\\smohs_\\Machine_Learning\\PrepZee\\Data_Superstore\\Sample - Superstore.xls",sheet_name="People")

# %%
hr=pd.read_csv("C:\\Users\\smohs_\\Machine_Learning\\PrepZee\\Data_Superstore\\Human Resource_employees2.csv")

# %%
churn= pd.read_csv("C:\\Users\\smohs_\\Machine_Learning\\PrepZee\\Data_Superstore\\Customer_Churn (2).csv")

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
hr.isnull().sum()
# Out:
# FIRST NAME          0
# LAST NAME           2
# SEX                 0
# DOJ                 1
# CURRENT DATE        0
# DESIGNATION         0
# AGE                 3
# SALARY              0
# UNIT                0
# LEAVES USED         3
# LEAVES REMAINING    2
# RATINGS             2
# PAST EXP            0
# dtype: int64

# %%
# #Missing Value
# Outliers
# Duplicate

# %%
hr.isna().sum()
# Out:
# FIRST NAME          0
# LAST NAME           2
# SEX                 0
# DOJ                 1
# CURRENT DATE        0
# DESIGNATION         0
# AGE                 3
# SALARY              0
# UNIT                0
# LEAVES USED         3
# LEAVES REMAINING    2
# RATINGS             2
# PAST EXP            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#Dropping the column

df_cleaned = df.dropna(axis=1)

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 62.8+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_clened01= df.dropna(subset=['Age','Cabin']) #

# %%
df_clened01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185 entries, 1 to 889
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  185 non-null    int64
#  1   Survived     185 non-null    int64
#  2   Pclass       185 non-null    int64
#  3   Name         185 non-null    object
#  4   Sex          185 non-null    object
#  5   Age          185 non-null    float64
#  6   SibSp        185 non-null    int64
#  7   Parch        185 non-null    int64
#  8   Ticket       185 non-null    object
#  9   Fare         185 non-null    float64
#  10  Cabin        185 non-null    object
#  11  Embarked     183 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 18.8+ KB

# %%
df_cleaned_V2 = df.drop(columns =['Cabin'])
df_cleaned_V2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
df_cleaned_V2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
df_fresh=df_cleaned_V2.dropna()

# %%
df_fresh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 712 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  712 non-null    int64
#  1   Survived     712 non-null    int64
#  2   Pclass       712 non-null    int64
#  3   Name         712 non-null    object
#  4   Sex          712 non-null    object
#  5   Age          712 non-null    float64
#  6   SibSp        712 non-null    int64
#  7   Parch        712 non-null    int64
#  8   Ticket       712 non-null    object
#  9   Fare         712 non-null    float64
#  10  Embarked     712 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 66.8+ KB

# %%
# # Task1: create a new dataset after deleting all the 
#            # missing value record from Age column from Titanic Dataset
    
# df_cleaned = df.dropna(subset=['Age']) # How many rows you are finally getting in this df_cleaned
# #_______________________________________________________________________________________________Task2: create a new dataset after deleting all the 
#            # missing value record from [Age Cabin and Embarked] columns from Titanic Dataset
#     td_cd1 = td.dropna(subset=['Age','Cabin','Embarked'])
# td_cd1
# #_________________________________________________________________________________
# # Task 3 - As we can see lot of the data loss happened because of the one
# # culprit - CABIN column so lets delete that column itself
# df_titanic = df_titanic.drop('Cabin',axis=1) # asix = 1 stands for column wise operations
# df_titanic.count()
# #_________________________________________________________________________________________
# # Task 4: so What and how to go finally considering the a bove situations ?
# ct =titanic.drop('Cabin',axis=1) # Dropping the column
# ct = ct.dropna(subset=['Age','Embarked']) # Deleting the missing entries record
# ct.count

# %%
# Outlier: Any extreme value is an outlier;

# %%
hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2639 entries, 0 to 2638
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   FIRST NAME        2639 non-null   object
#  1   LAST NAME         2637 non-null   object
#  2   SEX               2639 non-null   object
#  3   DOJ               2638 non-null   object
#  4   CURRENT DATE      2639 non-null   object
#  5   DESIGNATION       2639 non-null   object
#  6   AGE               2636 non-null   float64
#  7   SALARY            2639 non-null   int64
#  8   UNIT              2639 non-null   object
#  9   LEAVES USED       2636 non-null   float64
#  10  LEAVES REMAINING  2637 non-null   float64
#  11  RATINGS           2637 non-null   float64
#  12  PAST EXP          2639 non-null   int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 268.2+ KB

# %%
hr['Age1'] = df['Age'].fillna(df['Age'].median())
hr.head()
# Out:
#   FIRST NAME   LAST NAME SEX         DOJ CURRENT DATE DESIGNATION   AGE  \
# 0     TOMASA       ARMEN   F   5-18-2014   01-07-2016     Analyst  21.0
# 1      ANNIE         NaN   F         NaN   01-07-2016   Associate   NaN
# 2      OLIVE        ANCY   F   7-28-2014   01-07-2016     Analyst  21.0
# 3     CHERRY     AQUILAR   F  04-03-2013   01-07-2016     Analyst  22.0
# 4       LEON  ABOULAHOUD   M  11-20-2014   01-07-2016     Analyst   NaN
#
#    SALARY        UNIT  LEAVES USED  LEAVES REMAINING  RATINGS  PAST EXP  Age1
# 0   44570     Finance         24.0               6.0      2.0         0  22.0
# 1   89207         Web          NaN              13.0      NaN         7  38.0
# 2   40955     Finance         23.0               7.0      3.0         0  26.0
# 3   45550          IT         22.0               8.0      3.0         0  35.0
# 4   43161  Operations         27.0               3.0      NaN         3  35.0

# %%
hr['Age2'] = df['Age'].fillna(df['Age'].mean())

# %%
hr.head()
# Out:
#   FIRST NAME   LAST NAME SEX         DOJ CURRENT DATE DESIGNATION   AGE  \
# 0     TOMASA       ARMEN   F   5-18-2014   01-07-2016     Analyst  21.0
# 1      ANNIE         NaN   F         NaN   01-07-2016   Associate   NaN
# 2      OLIVE        ANCY   F   7-28-2014   01-07-2016     Analyst  21.0
# 3     CHERRY     AQUILAR   F  04-03-2013   01-07-2016     Analyst  22.0
# 4       LEON  ABOULAHOUD   M  11-20-2014   01-07-2016     Analyst   NaN
#
#    SALARY        UNIT  LEAVES USED  LEAVES REMAINING  RATINGS  PAST EXP  Age1  \
# 0   44570     Finance         24.0               6.0      2.0         0  22.0
# 1   89207         Web          NaN              13.0      NaN         7  38.0
# 2   40955     Finance         23.0               7.0      3.0         0  26.0
# 3   45550          IT         22.0               8.0      3.0         0  35.0
# 4   43161  Operations         27.0               3.0      NaN         3  35.0
#
#    Age2
# 0  22.0
# 1  38.0
# 2  26.0
# 3  35.0
# 4  35.0

# %%
df_cleaned_V2 = df.drop(columns =['Cabin'])hr.head()
# Out:
#   FIRST NAME   LAST NAME SEX         DOJ CURRENT DATE DESIGNATION   AGE  \
# 0     TOMASA       ARMEN   F   5-18-2014   01-07-2016     Analyst  21.0
# 1      ANNIE         NaN   F         NaN   01-07-2016   Associate   NaN
# 2      OLIVE        ANCY   F   7-28-2014   01-07-2016     Analyst  21.0
# 3     CHERRY     AQUILAR   F  04-03-2013   01-07-2016     Analyst  22.0
# 4       LEON  ABOULAHOUD   M  11-20-2014   01-07-2016     Analyst   NaN
#
#    SALARY        UNIT  LEAVES USED  LEAVES REMAINING  RATINGS  PAST EXP  Age1  \
# 0   44570     Finance         24.0               6.0      2.0         0  22.0
# 1   89207         Web          NaN              13.0      NaN         7  38.0
# 2   40955     Finance         23.0               7.0      3.0         0  26.0
# 3   45550          IT         22.0               8.0      3.0         0  35.0
# 4   43161  Operations         27.0               3.0      NaN         3  35.0
#
#    Age2
# 0  22.0
# 1  38.0
# 2  26.0
# 3  35.0
# 4  35.0

# %%
# df_cleaned_V2 = df.drop(columns =['Cabin'])

hr.drop(columns=['Age1','Age2'])
# Out:
#      FIRST NAME   LAST NAME SEX         DOJ CURRENT DATE     DESIGNATION  \
# 0        TOMASA       ARMEN   F   5-18-2014   01-07-2016         Analyst
# 1         ANNIE         NaN   F         NaN   01-07-2016       Associate
# 2         OLIVE        ANCY   F   7-28-2014   01-07-2016         Analyst
# 3        CHERRY     AQUILAR   F  04-03-2013   01-07-2016         Analyst
# 4          LEON  ABOULAHOUD   M  11-20-2014   01-07-2016         Analyst
# ...         ...         ...  ..         ...          ...             ...
# 2634  KATHERINE      ALSDON   F   6-28-2011   01-07-2016  Senior Manager
# 2635     LOUISE     ALTARAS   F   1-14-2014   01-07-2016         Analyst
# 2636      RENEE      ALVINO   F   1-23-2014   01-07-2016         Analyst
# 2637       TERI   ANASTASIO   F   3-17-2014   01-07-2016         Analyst
# 2638    GREGORY      ABARCA   M   9-18-2014   01-07-2016         Analyst
#
#        AGE  SALARY        UNIT  LEAVES USED  LEAVES REMAINING  RATINGS  \
# ...

# %%
hr['Age1'] = hr['AGE'].fillna(hr['AGE'].mean())
hr['Age2'] = hr['AGE'].fillna(hr['AGE'].median())
hr.head()
# Out:
#   FIRST NAME   LAST NAME SEX         DOJ CURRENT DATE DESIGNATION   AGE  \
# 0     TOMASA       ARMEN   F   5-18-2014   01-07-2016     Analyst  21.0
# 1      ANNIE         NaN   F         NaN   01-07-2016   Associate   NaN
# 2      OLIVE        ANCY   F   7-28-2014   01-07-2016     Analyst  21.0
# 3     CHERRY     AQUILAR   F  04-03-2013   01-07-2016     Analyst  22.0
# 4       LEON  ABOULAHOUD   M  11-20-2014   01-07-2016     Analyst   NaN
#
#    SALARY        UNIT  LEAVES USED  LEAVES REMAINING  RATINGS  PAST EXP  \
# 0   44570     Finance         24.0               6.0      2.0         0
# 1   89207         Web          NaN              13.0      NaN         7
# 2   40955     Finance         23.0               7.0      3.0         0
# 3   45550          IT         22.0               8.0      3.0         0
# 4   43161  Operations         27.0               3.0      NaN         3
#
#         Age1  Age2
# 0  21.000000  21.0
# 1  24.756449  24.0
# 2  21.000000  21.0
# ...

# %%
df_fresh.drop(columns= ['Ticket'],inplace = True)
# Out:
# C:\Users\smohs_\AppData\Local\Temp\ipykernel_252\2151955807.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fresh.drop(columns= ['Ticket'],inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
dummy_data={
    "Name" : ['RAM','RITA','RAM','RAM','Rakesh','Radha'],
    "AGE" : [20,22,20,28,30,25],
    "SEX" : ["m","f",'m','m','f','f'],
    "location" : ['Delhi','Bangalore','Delhi','Mumbai','Bangalore',"Chennai"]
    
      
}

dummy = pd.DataFrame (dummy_data)
dummy
# Out:
#      Name  AGE SEX   location
# 0     RAM   20   m      Delhi
# 1    RITA   22   f  Bangalore
# 2     RAM   20   m      Delhi
# 3     RAM   28   m     Mumbai
# 4  Rakesh   30   f  Bangalore
# 5   Radha   25   f    Chennai

# %%
dummy.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
# To identify the specific duplicate:
    
#     df.duplicated(subset=['Name','City'])

# %%
df_fresh.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   712.000000  712.000000  712.000000  712.000000  712.000000
# mean    448.589888    0.404494    2.240169   29.642093    0.514045
# std     258.683191    0.491139    0.836854   14.492933    0.930692
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     222.750000    0.000000    1.000000   20.000000    0.000000
# 50%     445.000000    0.000000    2.000000   28.000000    0.000000
# 75%     677.250000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    5.000000
#
#             Parch        Fare
# count  712.000000  712.000000
# mean     0.432584   34.567251
# std      0.854181   52.938648
# min      0.000000    0.000000
# 25%      0.000000    8.050000
# 50%      0.000000   15.645850
# 75%      1.000000   33.000000
# max      6.000000  512.329200

# %% [markdown]
# # Detecting and Managing outliers

# %%
hr.head()
# Out:
#   FIRST NAME   LAST NAME SEX         DOJ CURRENT DATE DESIGNATION   AGE  \
# 0     TOMASA       ARMEN   F   5-18-2014   01-07-2016     Analyst  21.0
# 1      ANNIE         NaN   F         NaN   01-07-2016   Associate   NaN
# 2      OLIVE        ANCY   F   7-28-2014   01-07-2016     Analyst  21.0
# 3     CHERRY     AQUILAR   F  04-03-2013   01-07-2016     Analyst  22.0
# 4       LEON  ABOULAHOUD   M  11-20-2014   01-07-2016     Analyst   NaN
#
#    SALARY        UNIT  LEAVES USED  LEAVES REMAINING  RATINGS  PAST EXP  \
# 0   44570     Finance         24.0               6.0      2.0         0
# 1   89207         Web          NaN              13.0      NaN         7
# 2   40955     Finance         23.0               7.0      3.0         0
# 3   45550          IT         22.0               8.0      3.0         0
# 4   43161  Operations         27.0               3.0      NaN         3
#
#         Age1  Age2
# 0  21.000000  21.0
# 1  24.756449  24.0
# 2  21.000000  21.0
# ...

# %%
hr['age3'] = hr.AGE.clip(lower =25,upper =40)
hr.head()
# Out:
#   FIRST NAME   LAST NAME SEX         DOJ CURRENT DATE DESIGNATION   AGE  \
# 0     TOMASA       ARMEN   F   5-18-2014   01-07-2016     Analyst  21.0
# 1      ANNIE         NaN   F         NaN   01-07-2016   Associate   NaN
# 2      OLIVE        ANCY   F   7-28-2014   01-07-2016     Analyst  21.0
# 3     CHERRY     AQUILAR   F  04-03-2013   01-07-2016     Analyst  22.0
# 4       LEON  ABOULAHOUD   M  11-20-2014   01-07-2016     Analyst   NaN
#
#    SALARY        UNIT  LEAVES USED  LEAVES REMAINING  RATINGS  PAST EXP  \
# 0   44570     Finance         24.0               6.0      2.0         0
# 1   89207         Web          NaN              13.0      NaN         7
# 2   40955     Finance         23.0               7.0      3.0         0
# 3   45550          IT         22.0               8.0      3.0         0
# 4   43161  Operations         27.0               3.0      NaN         3
#
#         Age1  Age2  age3
# 0  21.000000  21.0  25.0
# 1  24.756449  24.0   NaN
# ...

# %%
hr.age3.describe()
# Out:
# count    2636.000000
# mean       26.202959
# std         2.963306
# min        25.000000
# 25%        25.000000
# 50%        25.000000
# 75%        25.000000
# max        40.000000
# Name: age3, dtype: float64

# %%
df_fresh
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_fresh['Age1'] = df_fresh.Age.clip(lower =25,upper =40)
df_fresh.head()
# Out:
# C:\Users\smohs_\AppData\Local\Temp\ipykernel_252\2602860522.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fresh['Age1'] = df_fresh.Age.clip(lower =25,upper =40)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# ...

# %%
df_fresh.Age1.describe()
# Out:
# count    712.000000
# mean      30.787921
# std        6.242517
# min       25.000000
# 25%       25.000000
# 50%       28.000000
# 75%       38.000000
# max       40.000000
# Name: Age1, dtype: float64

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\smohs_
